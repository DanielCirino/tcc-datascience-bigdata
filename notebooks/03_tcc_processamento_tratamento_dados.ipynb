# %%
from time import time
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import csv

# %matplotlib inline
pd.set_option('display.max_colwidth', -1)
sns.set_theme(style="darkgrid")

DIR_DATASET = r'/Users/dev-rocks/Documents/TCC - Data Science e Big Data/Projeto/datasets/'
# DIR_DATASET = r'C:\Users\Daniel.Vale\Personal\PBDDC\TCC\Projeto_v2\datasets\\'

# %%
dfProposicoes = pd.read_csv(f'{DIR_DATASET}proposicoes.csv', sep=';', low_memory=False)
dfTemasProposicoes = pd.read_csv(f'{DIR_DATASET}temas.csv', sep=';', low_memory=False)
dfInteiroTeor = pd.read_csv(f'{DIR_DATASET}inteiroTeor.csv', sep=';', low_memory=False)

# %%
dfProposicoes.info()
qtdIdsDuplicados = dfProposicoes.duplicated(subset='id').sum()
print(f'\n[INFO  ] Quantidade de IDs duplicados: {qtdIdsDuplicados}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126398 entries, 0 to 126397
# Data columns (total 31 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   id                                126398 non-null  int64
#  1   uri                               126398 non-null  object
#  2   siglaTipo                         126398 non-null  object
#  3   numero                            126398 non-null  int64
#  4   ano                               126398 non-null  int64
#  5   codTipo                           126398 non-null  int64
#  6   descricaoTipo                     126398 non-null  object
#  7   ementa                            122242 non-null  object
#  8   ementaDetalhada                   1467 non-null    object
#  9   keywords                          20047 non-null   object
#  10  dataApresentacao                  126398 non-null  object
#  11  uriOrgaoNumerador                 126398 non-null  object
#  12  uriPropAnterior                   0 non-null       float64
#  13  uriPropPrincipal                  91030 non-null   object
#  14  uriPropPosterior                  21 non-null      object
#  15  urlInteiroTeor                    125762 non-null  object
#  16  urnFinal                          0 non-null       float64
#  17  ultimoStatus_dataHora             126398 non-null  object
#  18  ultimoStatus_sequencia            126398 non-null  int64
#  19  ultimoStatus_uriRelator           13805 non-null   object
#  20  ultimoStatus_idOrgao              51943 non-null   float64
#  21  ultimoStatus_siglaOrgao           51940 non-null   object
#  22  ultimoStatus_uriOrgao             51943 non-null   object
#  23  ultimoStatus_regime               23775 non-null   object
#  24  ultimoStatus_descricaoTramitacao  126398 non-null  object
#  25  ultimoStatus_idTipoTramitacao     126398 non-null  int64
#  26  ultimoStatus_descricaoSituacao    51943 non-null   object
#  27  ultimoStatus_idSituacao           51943 non-null   float64
#  28  ultimoStatus_despacho             126389 non-null  object
#  29  ultimoStatus_url                  82658 non-null   object
#  30  anoDataset                        126398 non-null  int64
# dtypes: float64(4), int64(7), object(20)
# memory usage: 29.9+ MB
#
# [INFO  ] Quantidade de IDs duplicados: 0

# %%
ax = sns.countplot(x='anoDataset',data=dfProposicoes)
ax.set_xlabel('Ano')
ax.set_ylabel('Quantidade')
ax.plot()
# Out:
# []

# %%
dfProposicoes.groupby(['anoDataset']).size()
# Out:
# anoDataset
# 2018    18712
# 2019    38246
# 2020    29676
# 2021    39764
# dtype: int64

# %%
dfTemasProposicoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53268 entries, 0 to 53267
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   uriProposicao  53268 non-null  object
#  1   siglaTipo      53268 non-null  object
#  2   numero         53268 non-null  int64
#  3   ano            53268 non-null  int64
#  4   codTema        53268 non-null  int64
#  5   tema           53268 non-null  object
#  6   relevancia     53268 non-null  int64
#  7   anoDataset     53268 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 3.3+ MB

# %%
dfTemasProposicoes.groupby(['ano', 'anoDataset']).size()
# Out:
# ano   anoDataset
# 2018  2018           5097
# 2019  2019          14251
# 2020  2020          19004
# 2021  2021          14916
# dtype: int64

# %%
ax = sns.countplot(x='anoDataset',data=dfTemasProposicoes)

# %%
dfTemasProposicoes.groupby(['tema']).size()
# Out:
# tema
# Administração Pública                          4957
# Agricultura, Pecuária, Pesca e Extrativismo    1030
# Arte, Cultura e Religião                        651
# Cidades e Desenvolvimento Urbano                993
# Ciência, Tecnologia e Inovação                  544
# Ciências Exatas e da Terra                        3
# Ciências Sociais e Humanas                        6
# Comunicações                                   1979
# Defesa e Segurança                             2210
# Direito Civil e Processual Civil               1007
# Direito Constitucional                          159
# Direito Penal e Processual Penal               2033
# Direito e Defesa do Consumidor                 1183
# Direito e Justiça                               296
# Direitos Humanos e Minorias                    5193
# Economia                                       1727
# Educação                                       3011
# Energia, Recursos Hídricos e Minerais          1361
# Esporte e Lazer                                 451
# Estrutura Fundiária                             253
# Finanças Públicas e Orçamento                  4529
# Homenagens e Datas Comemorativas                975
# Indústria, Comércio e Serviços                 1748
# Meio Ambiente e Desenvolvimento Sustentável    1725
# Política, Partidos e Eleições                   537
# Previdência e Assistência Social               1565
# Processo Legislativo e Atuação Parlamentar      535
# Relações Internacionais e Comércio Exterior     636
# Saúde                                          6633
# Trabalho e Emprego                             3019
# Turismo                                         218
# Viação, Transporte e Mobilidade                2101
# dtype: int64

# %%
dfTemasProposicoes.groupby(['uriProposicao']).size()
# Out:
# uriProposicao
# https://dadosabertos.camara.leg.br/api/v2/proposicoes/1299572    3
# https://dadosabertos.camara.leg.br/api/v2/proposicoes/1299577    1
# https://dadosabertos.camara.leg.br/api/v2/proposicoes/1555295    1
# https://dadosabertos.camara.leg.br/api/v2/proposicoes/2057848    2
# https://dadosabertos.camara.leg.br/api/v2/proposicoes/2057934    2
#                                                                 ..
# https://dadosabertos.camara.leg.br/api/v2/proposicoes/593065     1
# https://dadosabertos.camara.leg.br/api/v2/proposicoes/601739     2
# https://dadosabertos.camara.leg.br/api/v2/proposicoes/614512     1
# https://dadosabertos.camara.leg.br/api/v2/proposicoes/946475     2
# https://dadosabertos.camara.leg.br/api/v2/proposicoes/946514     1
# Length: 30491, dtype: int64

# %%
dfPreposicoesTemas = pd.merge(dfTemasProposicoes, dfProposicoes, left_on='uriProposicao', right_on='uri')
qtdProposicoesClassificadas = len(dfPreposicoesTemas.groupby(['id']).nunique())
print(f'[INFO    ] Total de proposições classificadas: {qtdProposicoesClassificadas}')
# Out:
# [INFO    ] Total de proposições classificadas: 30491

# %%
dfInteiroTeor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126398 entries, 0 to 126397
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              126398 non-null  int64
#  1   urlInteiroTeor  125762 non-null  object
#  2   statusExtracao  126398 non-null  int64
#  3   tipoDocumento   126398 non-null  object
#  4   tamanhoEmBytes  126398 non-null  int64
#  5   inteiroTeor     118204 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 5.8+ MB

# %%
dfInteiroTeor.loc[(dfInteiroTeor['statusExtracao']==5)&(dfInteiroTeor['inteiroTeor'].isnull())][['urlInteiroTeor','statusExtracao','inteiroTeor']]
# Out:
#                                            urlInteiroTeor  statusExtracao  \
# 18      http://www.camara.gov.br/proposicoesWeb/prop_m...               5
# 19      http://www.camara.gov.br/proposicoesWeb/prop_m...               5
# 326     http://www.camara.gov.br/proposicoesWeb/prop_m...               5
# 2304    http://www.camara.gov.br/proposicoesWeb/prop_m...               5
# 2373    http://www.camara.gov.br/proposicoesWeb/prop_m...               5
# ...                                                   ...             ...
# 126393  http://www.camara.gov.br/proposicoesWeb/prop_m...               5
# 126394  http://www.camara.gov.br/proposicoesWeb/prop_m...               5
# 126395  http://www.camara.gov.br/proposicoesWeb/prop_m...               5
# 126396  http://www.camara.gov.br/proposicoesWeb/prop_m...               5
# 126397  http://www.camara.gov.br/proposicoesWeb/prop_m...               5
#
#        inteiroTeor
# 18             NaN
# 19             NaN
# 326            NaN
# 2304           NaN
# 2373           NaN
# ...            ...
# 126393         NaN
# 126394         NaN
# 126395         NaN
# 126396         NaN
# 126397         NaN
#
# [7391 rows x 3 columns]

# %%
dfInteiroTeor.loc[2373]['urlInteiroTeor']
# Out:
# 'http://www.camara.gov.br/proposicoesWeb/prop_mostrarintegra?codteor=1715290'

# %%
ax = sns.countplot(x='statusExtracao',data=dfInteiroTeor.loc[dfInteiroTeor['statusExtracao']!=1])

# %%
dfInteiroTeor.groupby(['statusExtracao']).count()
# Out:
#                     id  urlInteiroTeor  tipoDocumento  tamanhoEmBytes  \
# statusExtracao
# 1               118204          118204         118204          118204
# 2                   97              97             97              97
# 3                   70              70             70              70
# 4                  636               0            636             636
# 5                 7391            7391           7391            7391
#
#                 inteiroTeor
# statusExtracao
# 1                    118204
# 2                         0
# 3                         0
# 4                         0
# 5                         0

# %%
dfInteiroTeor.groupby(['tipoDocumento']).count()
# Out:
#                                                         id  urlInteiroTeor  \
# tipoDocumento
# ('/Contents',)                                           4               4
# ('Cannot read an empty file',)                          52              52
# ('Error -5 while decompressing data: incomplete...       1               1
# ('Multiple definitions in dictionary at byte 0x...       1               1
# ('Multiple definitions in dictionary at byte 0x...       1               1
# (ProtocolError('Connection aborted.', OSError(5...       1               1
# (ProtocolError('Connection aborted.', RemoteDis...       7               7
# (ReadTimeoutError("HTTPConnectionPool(host='www...       1               1
# (ReadTimeoutError("HTTPSConnectionPool(host='ww...       1               1
# ([<class 'decimal.ConversionSyntax'>],)                  1               1
# Proposicao s/ url inteiro teor                         636               0
# application/msword                                      97              97
# application/pdf                                     118108          118108
# imagem salva como pdf                                 7391            7391
# text/html;charset=utf-8                                 96              96
#
#                                                     statusExtracao  \
# tipoDocumento
# ('/Contents',)                                                   4
# ('Cannot read an empty file',)                                  52
# ('Error -5 while decompressing data: incomplete...               1
# ('Multiple definitions in dictionary at byte 0x...               1
# ('Multiple definitions in dictionary at byte 0x...               1
# (ProtocolError('Connection aborted.', OSError(5...               1
# (ProtocolError('Connection aborted.', RemoteDis...               7
# (ReadTimeoutError("HTTPConnectionPool(host='www...               1
# (ReadTimeoutError("HTTPSConnectionPool(host='ww...               1
# ([<class 'decimal.ConversionSyntax'>],)                          1
# Proposicao s/ url inteiro teor                                 636
# application/msword                                              97
# application/pdf                                             118108
# imagem salva como pdf                                         7391
# text/html;charset=utf-8                                         96
#
#                                                     tamanhoEmBytes  \
# tipoDocumento
# ('/Contents',)                                                   4
# ('Cannot read an empty file',)                                  52
# ('Error -5 while decompressing data: incomplete...               1
# ('Multiple definitions in dictionary at byte 0x...               1
# ('Multiple definitions in dictionary at byte 0x...               1
# (ProtocolError('Connection aborted.', OSError(5...               1
# (ProtocolError('Connection aborted.', RemoteDis...               7
# (ReadTimeoutError("HTTPConnectionPool(host='www...               1
# (ReadTimeoutError("HTTPSConnectionPool(host='ww...               1
# ([<class 'decimal.ConversionSyntax'>],)                          1
# Proposicao s/ url inteiro teor                                 636
# application/msword                                              97
# application/pdf                                             118108
# imagem salva como pdf                                         7391
# text/html;charset=utf-8                                         96
#
#                                                     inteiroTeor
# tipoDocumento
# ('/Contents',)                                                0
# ('Cannot read an empty file',)                                0
# ('Error -5 while decompressing data: incomplete...            0
# ('Multiple definitions in dictionary at byte 0x...            0
# ('Multiple definitions in dictionary at byte 0x...            0
# (ProtocolError('Connection aborted.', OSError(5...            0
# (ProtocolError('Connection aborted.', RemoteDis...            0
# (ReadTimeoutError("HTTPConnectionPool(host='www...            0
# (ReadTimeoutError("HTTPSConnectionPool(host='ww...            0
# ([<class 'decimal.ConversionSyntax'>],)                       0
# Proposicao s/ url inteiro teor                                0
# application/msword                                            0
# application/pdf                                          118108
# imagem salva como pdf                                         0
# text/html;charset=utf-8                                      96

# %%
dfPercentualStatus = dfInteiroTeor.groupby(['statusExtracao']).count()
dfPercentualStatus['%'] = dfPercentualStatus['id']/len(dfInteiroTeor)*100
dfPercentualStatus[['id','%']]
# Out:
#                     id          %
# statusExtracao
# 1               118204  93.517302
# 2                   97   0.076742
# 3                   70   0.055381
# 4                  636   0.503173
# 5                 7391   5.847403

# %%
dfTamanhoConteudo = dfInteiroTeor.loc[dfInteiroTeor['statusExtracao']==1]\
.groupby(['tipoDocumento'])\
.agg({'tamanhoEmBytes': 'sum'})

tamanhoEmGigas = dfTamanhoConteudo.agg({'tamanhoEmBytes': 'sum'})/1e+9
tamanhoEmGigas = tamanhoEmGigas['tamanhoEmBytes']

print(f'[INFO    ] Tamanho dos documentos extraídos e processados: {tamanhoEmGigas:0.2f} GB')
dfTamanhoConteudo
# Out:
# [INFO    ] Tamanho dos documentos extraídos e processados: 108.38 GB
#                          tamanhoEmBytes
# tipoDocumento
# application/pdf            108380121493
# text/html;charset=utf-8          266750

# %%
def tokenizarTexto(texto: str,listaStopWords=[]):
    try:
        tamanhoTexto = len(texto.strip().split())
        
        pontuacao = ['{', '}','(', ')', ';', ':', '[', ']','#','%','*', '<','>','=','?',
                     ',', '-','_', '.', '$', '!', '?', '°', '§', '+','@',
                     'º', '/', '"', '\'','~','Ł','·','&','ˇ','ˆ','˝','˚','˛','˙','˘','˜','˝']
        texto = texto.replace('\\n', ' ')
        
        for ponto in pontuacao:
            texto = texto.replace(ponto, ' ')

        for numero in range(0, 10):
            texto = texto.replace(str(numero), '')

        tokens = texto.strip().split()
        palavrasChave = [palavra for palavra in tokens if not palavra.lower() in listaStopWords and len(palavra)>3]
        
       
        return (' '.join(palavrasChave).lower(), tamanhoTexto, len(palavrasChave))
    except Exception as e:
        print(f'[ERRO    ] Erro ao tokenizar texto: "{texto}" \n{e}')
        raise e

# %%
colunasProposicao=['id','uri','ementa','descricaoTipo','anoDataset']
colunasTemas=['uriProposicao','tema']
colunasInteiroTeor=['id','urlInteiroTeor','statusExtracao','tipoDocumento','tamanhoEmBytes','inteiroTeor']

dfProposicoes = pd.read_csv(f'{DIR_DATASET}proposicoes.csv', sep=';', low_memory=False, usecols=colunasProposicao)
dfTemasProposicoes = pd.read_csv(f'{DIR_DATASET}temas.csv', sep=';', low_memory=False, usecols=colunasTemas)
dfInteiroTeor = pd.read_csv(f'{DIR_DATASET}inteiroTeor.csv', sep=';', low_memory=False, usecols=colunasInteiroTeor)

dfProposicoes.info()
dfTemasProposicoes.info()
dfInteiroTeor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126398 entries, 0 to 126397
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             126398 non-null  int64
#  1   uri            126398 non-null  object
#  2   descricaoTipo  126398 non-null  object
#  3   ementa         122242 non-null  object
#  4   anoDataset     126398 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 4.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53268 entries, 0 to 53267
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   uriProposicao  53268 non-null  object
#  1   tema           53268 non-null  object
# dtypes: object(2)
# memory usage: 832.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126398 entries, 0 to 126397
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              126398 non-null  int64
#  1   urlInteiroTeor  125762 non-null  object
#  2   statusExtracao  126398 non-null  int64
#  3   tipoDocumento   126398 non-null  object
#  4   tamanhoEmBytes  126398 non-null  int64
#  5   inteiroTeor     118204 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 5.8+ MB

# %%
dfAuxiliar = pd.merge(dfProposicoes,dfInteiroTeor,left_on='id',right_on='id')
dfAuxiliar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126398 entries, 0 to 126397
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              126398 non-null  int64
#  1   uri             126398 non-null  object
#  2   descricaoTipo   126398 non-null  object
#  3   ementa          122242 non-null  object
#  4   anoDataset      126398 non-null  int64
#  5   urlInteiroTeor  125762 non-null  object
#  6   statusExtracao  126398 non-null  int64
#  7   tipoDocumento   126398 non-null  object
#  8   tamanhoEmBytes  126398 non-null  int64
#  9   inteiroTeor     118204 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 10.6+ MB

# %%
dfUnificado = pd.merge(dfAuxiliar,dfTemasProposicoes,left_on='uri',right_on='uriProposicao',how='left')
dfUnificado['tokens'] = np.NaN
dfUnificado['qtdTokens'] = 0
dfUnificado['semConteudo'] = pd.isna(dfUnificado['ementa']) & pd.isna(dfUnificado['inteiroTeor'])
dfUnificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149175 entries, 0 to 149174
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              149175 non-null  int64
#  1   uri             149175 non-null  object
#  2   descricaoTipo   149175 non-null  object
#  3   ementa          145019 non-null  object
#  4   anoDataset      149175 non-null  int64
#  5   urlInteiroTeor  148537 non-null  object
#  6   statusExtracao  149175 non-null  int64
#  7   tipoDocumento   149175 non-null  object
#  8   tamanhoEmBytes  149175 non-null  int64
#  9   inteiroTeor     140584 non-null  object
#  10  uriProposicao   53268 non-null   object
#  11  tema            53268 non-null   object
#  12  tokens          0 non-null       float64
#  13  semConteudo     149175 non-null  bool
# dtypes: bool(1), float64(1), int64(4), object(8)
# memory usage: 16.1+ MB

# %%
dfUnificado.groupby(['semConteudo']).size().sort_values(ascending=False).head(50)
# Out:
# semConteudo
# False    148186
# True     989
# dtype: int64

# %%
def tokenizarDataset(df,qtdLimite=0):
    try:
        dfStopWords = pd.read_csv(f'{DIR_DATASET}stop_words.csv', usecols=['stop_words']) \
                .replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["", ""])

        listaStopWords = dfStopWords['stop_words'].values.tolist()
        print(f'[INFO    ] Quantidade de stop words: {len(listaStopWords)}')
        
        dfParaExtracao = df.loc[df['tokens'].isnull()]
        print(f'[INFO    ] Proposicoes para tokenização: {len(dfParaExtracao)}')

        contador = 0
        contadorNulos = 0
        t0 = time()
        for index,linha in dfParaExtracao.iterrows():
            if  not linha['semConteudo']:
                ementa = '' if pd.isna(linha['ementa']) else linha['ementa']
                inteiroTeor = '' if pd.isna(linha['inteiroTeor']) else linha['inteiroTeor']
                idProposicao = linha['id']

                tokens, tamanhoInicial, tamanhoFinal = tokenizarTexto(f'{ementa} {inteiroTeor}',listaStopWords)

                df.loc[df['id']==idProposicao,['ementa',
                                               'inteiroTeor',
                                               'tokens',
                                              'qtdTokens']] = [ementa.strip(),inteiroTeor.strip(),tokens,len(tokens.split())]


                if contador%1000==0:
                    zeros = (6-len(str(contador)))*'0'
                    print(f'[INFO    ] [{zeros}{contador}][{idProposicao}]Palavras: {tamanhoInicial} \
                    | Tokens: {tamanhoFinal} \
                    | Redução: {(tamanhoInicial-tamanhoFinal)/tamanhoInicial*100:.0f}%')
                    
                if contador%10000==0:
                    df.to_csv(f'{DIR_DATASET}/proposicoesUnificado_v2.csv',
                              index=False,sep=';',quoting=csv.QUOTE_ALL,  escapechar="\\")
                    print('.' * 80 )
                    
                if qtdLimite>0 and contador ==qtdLimite:
                    break

                contador+=1
            else:
                contadorNulos+=1
                
        duracao = time()-t0
        print(f'[INFO    ] Tokenizado {contador} proposicoes em {duracao:.0f} segundos. Media={(contador/duracao):.2f} prop/seg' )
        print(f'[INFO    ] Proposições sem ementa e sem inteiro teor: {contadorNulos}' )
        
        
    except Exception as e:
        print(f'[ERRO    ] Erro ao tokenizar dataset: {e.args}')
        print(f'[ERRO    ] Ementa: {ementa} \n Teor: {inteiroTeor}')
        raise e
    finally:
        df.to_csv(f'{DIR_DATASET}/proposicoesUnificado_v2.csv',index=False,sep=';',quoting=csv.QUOTE_ALL,  escapechar="\\")

# %%
tokenizarDataset(dfUnificado)
# Out:
# [INFO    ] Quantidade de stop words: 596
# [INFO    ] Proposicoes para tokenização: 129168
# [INFO    ] [000000][2211661]Palavras: 252                     | Tokens: 124                     | Redução: 51%
# ................................................................................
# [INFO    ] [001000][2212825]Palavras: 8                     | Tokens: 1                     | Redução: 88%
# [INFO    ] [002000][2214015]Palavras: 542                     | Tokens: 227                     | Redução: 58%
# [INFO    ] [003000][2215028]Palavras: 720                     | Tokens: 278                     | Redução: 61%
# [INFO    ] [004000][2216065]Palavras: 1385                     | Tokens: 567                     | Redução: 59%
# [INFO    ] [005000][2217390]Palavras: 571                     | Tokens: 274                     | Redução: 52%
# [INFO    ] [006000][2218457]Palavras: 429                     | Tokens: 177                     | Redução: 59%
# [INFO    ] [007000][2219564]Palavras: 165                     | Tokens: 69                     | Redução: 58%
# [INFO    ] [008000][2220644]Palavras: 407                     | Tokens: 188                     | Redução: 54%
# [INFO    ] [009000][2221719]Palavras: 453                     | Tokens: 218                     | Redução: 52%
# [INFO    ] [010000][2222863]Palavras: 106                     | Tokens: 12                     | Redução: 89%
# ................................................................................
# [INFO    ] [011000][2223895]Palavras: 2020                     | Tokens: 949                     | Redução: 53%
# [INFO    ] [012000][2224966]Palavras: 540                     | Tokens: 227                     | Redução: 58%
# [INFO    ] [013000][2226052]Palavras: 46                     | Tokens: 18                     | Redução: 61%
# [INFO    ] [014000][2227119]Palavras: 573                     | Tokens: 253                     | Redução: 56%
# [INFO    ] [015000][2228214]Palavras: 87                     | Tokens: 8                     | Redução: 91%
# [INFO    ] [016000][2229271]Palavras: 1288                     | Tokens: 557                     | Redução: 57%
# [INFO    ] [017000][2230275]Palavras: 1864                     | Tokens: 724                     | Redução: 61%
# [INFO    ] [018000][2231326]Palavras: 974                     | Tokens: 404                     | Redução: 59%
# [INFO    ] [019000][2232464]Palavras: 10741                     | Tokens: 4171                     | Redução: 61%
# [INFO    ] [020000][2233492]Palavras: 18                     | Tokens: 8                     | Redução: 56%
# ................................................................................
# [INFO    ] [021000][2234538]Palavras: 3499                     | Tokens: 1538                     | Redução: 56%
# [INFO    ] [022000][2167564]Palavras: 129                     | Tokens: 57                     | Redução: 56%
# [INFO    ] [023000][2168779]Palavras: 578                     | Tokens: 235                     | Redução: 59%
# [INFO    ] [024000][2170009]Palavras: 204                     | Tokens: 98                     | Redução: 52%
# [INFO    ] [025000][2171176]Palavras: 1275                     | Tokens: 497                     | Redução: 61%
# [INFO    ] [026000][2172333]Palavras: 1560                     | Tokens: 596                     | Redução: 62%
# [INFO    ] [027000][2173484]Palavras: 969                     | Tokens: 471                     | Redução: 51%
# [INFO    ] [028000][2174631]Palavras: 668                     | Tokens: 281                     | Redução: 58%
# [INFO    ] [029000][2175739]Palavras: 212                     | Tokens: 96                     | Redução: 55%
# [INFO    ] [030000][2176883]Palavras: 397                     | Tokens: 188                     | Redução: 53%
# ................................................................................
# [INFO    ] [031000][2177992]Palavras: 12                     | Tokens: 7                     | Redução: 42%
# [INFO    ] [032000][2179187]Palavras: 220                     | Tokens: 101                     | Redução: 54%
# [INFO    ] [033000][2180417]Palavras: 1917                     | Tokens: 721                     | Redução: 62%
# [INFO    ] [034000][2181573]Palavras: 762                     | Tokens: 322                     | Redução: 58%
# [INFO    ] [035000][2182659]Palavras: 980                     | Tokens: 385                     | Redução: 61%
# [INFO    ] [036000][2183717]Palavras: 522                     | Tokens: 205                     | Redução: 61%
# [INFO    ] [037000][2184764]Palavras: 370                     | Tokens: 167                     | Redução: 55%
# [INFO    ] [038000][2185816]Palavras: 301                     | Tokens: 138                     | Redução: 54%
# [INFO    ] [039000][2187037]Palavras: 550                     | Tokens: 251                     | Redução: 54%
# [INFO    ] [040000][2188195]Palavras: 518                     | Tokens: 228                     | Redução: 56%
# ................................................................................
# [INFO    ] [041000][2189372]Palavras: 35                     | Tokens: 18                     | Redução: 49%
# [INFO    ] [042000][2236276]Palavras: 537                     | Tokens: 232                     | Redução: 57%
# [INFO    ] [043000][2237125]Palavras: 123                     | Tokens: 52                     | Redução: 58%
# [INFO    ] [044000][2238199]Palavras: 144                     | Tokens: 50                     | Redução: 65%
# [INFO    ] [045000][2239067]Palavras: 600                     | Tokens: 260                     | Redução: 57%
# [INFO    ] [046000][2239755]Palavras: 256                     | Tokens: 86                     | Redução: 66%
# [INFO    ] [047000][2240750]Palavras: 536                     | Tokens: 218                     | Redução: 59%
# [INFO    ] [048000][2241670]Palavras: 1044                     | Tokens: 453                     | Redução: 57%
# [INFO    ] [049000][2242170]Palavras: 260                     | Tokens: 13                     | Redução: 95%
# [INFO    ] [050000][2242701]Palavras: 28                     | Tokens: 14                     | Redução: 50%
# ................................................................................
# [INFO    ] [051000][2243419]Palavras: 602                     | Tokens: 295                     | Redução: 51%
# [INFO    ] [052000][2244327]Palavras: 217                     | Tokens: 81                     | Redução: 63%
# [INFO    ] [053000][2245245]Palavras: 558                     | Tokens: 244                     | Redução: 56%
# [INFO    ] [054000][2246245]Palavras: 390                     | Tokens: 120                     | Redução: 69%
# [INFO    ] [055000][2247166]Palavras: 1183                     | Tokens: 420                     | Redução: 64%
# [INFO    ] [056000][2248021]Palavras: 513                     | Tokens: 241                     | Redução: 53%
# [INFO    ] [057000][2248885]Palavras: 245                     | Tokens: 112                     | Redução: 54%
# [INFO    ] [058000][2249847]Palavras: 72                     | Tokens: 34                     | Redução: 53%
# [INFO    ] [059000][2250559]Palavras: 75                     | Tokens: 23                     | Redução: 69%
# [INFO    ] [060000][2251339]Palavras: 329                     | Tokens: 140                     | Redução: 57%
# ................................................................................
# [INFO    ] [061000][2252052]Palavras: 227                     | Tokens: 31                     | Redução: 86%
# [INFO    ] [062000][2252794]Palavras: 137                     | Tokens: 22                     | Redução: 84%
# [INFO    ] [063000][2253576]Palavras: 116                     | Tokens: 25                     | Redução: 78%
# [INFO    ] [064000][2254288]Palavras: 237                     | Tokens: 96                     | Redução: 59%
# [INFO    ] [065000][2254986]Palavras: 207                     | Tokens: 17                     | Redução: 92%
# [INFO    ] [066000][2255768]Palavras: 53                     | Tokens: 6                     | Redução: 89%
# [INFO    ] [067000][2256535]Palavras: 1177                     | Tokens: 476                     | Redução: 60%
# [INFO    ] [068000][2257312]Palavras: 363                     | Tokens: 171                     | Redução: 53%
# [INFO    ] [069000][2258131]Palavras: 157                     | Tokens: 7                     | Redução: 96%
# [INFO    ] [070000][2258899]Palavras: 25                     | Tokens: 3                     | Redução: 88%
# ................................................................................
# [INFO    ] [071000][2259695]Palavras: 155                     | Tokens: 16                     | Redução: 90%
# [INFO    ] [072000][2260503]Palavras: 226                     | Tokens: 21                     | Redução: 91%
# [INFO    ] [073000][2261199]Palavras: 368                     | Tokens: 53                     | Redução: 86%
# [INFO    ] [074000][2262102]Palavras: 75                     | Tokens: 17                     | Redução: 77%
# [INFO    ] [075000][2262896]Palavras: 24                     | Tokens: 3                     | Redução: 88%
# [INFO    ] [076000][2263611]Palavras: 929                     | Tokens: 362                     | Redução: 61%
# [INFO    ] [077000][2264373]Palavras: 730                     | Tokens: 120                     | Redução: 84%
# [INFO    ] [078000][2265050]Palavras: 1363                     | Tokens: 513                     | Redução: 62%
# [INFO    ] [079000][2265710]Palavras: 1587                     | Tokens: 704                     | Redução: 56%
# [INFO    ] [080000][2266687]Palavras: 68                     | Tokens: 12                     | Redução: 82%
# ................................................................................
# [INFO    ] [081000][2267662]Palavras: 155                     | Tokens: 46                     | Redução: 70%
# [INFO    ] [082000][2268530]Palavras: 26                     | Tokens: 6                     | Redução: 77%
# [INFO    ] [083000][2269218]Palavras: 294                     | Tokens: 119                     | Redução: 60%
# [INFO    ] [084000][2270087]Palavras: 72                     | Tokens: 16                     | Redução: 78%
# [INFO    ] [085000][2270837]Palavras: 102                     | Tokens: 23                     | Redução: 77%
# [INFO    ] [086000][2271758]Palavras: 176                     | Tokens: 53                     | Redução: 70%
# [INFO    ] [087000][2273546]Palavras: 445                     | Tokens: 22                     | Redução: 95%
# [INFO    ] [088000][2274510]Palavras: 1171                     | Tokens: 477                     | Redução: 59%
# [INFO    ] [089000][2275461]Palavras: 487                     | Tokens: 131                     | Redução: 73%
# [INFO    ] [090000][2276461]Palavras: 10                     | Tokens: 5                     | Redução: 50%
# ................................................................................
# [INFO    ] [091000][2277411]Palavras: 42                     | Tokens: 6                     | Redução: 86%
# [INFO    ] [092000][2278312]Palavras: 35                     | Tokens: 5                     | Redução: 86%
# [INFO    ] [093000][2279285]Palavras: 101                     | Tokens: 37                     | Redução: 63%
# [INFO    ] [094000][2280225]Palavras: 629                     | Tokens: 14                     | Redução: 98%
# [INFO    ] [095000][2281520]Palavras: 8                     | Tokens: 1                     | Redução: 88%
# [INFO    ] [096000][2282480]Palavras: 127                     | Tokens: 44                     | Redução: 65%
# [INFO    ] [097000][2283463]Palavras: 258                     | Tokens: 15                     | Redução: 94%
# [INFO    ] [098000][2284473]Palavras: 19                     | Tokens: 3                     | Redução: 84%
# [INFO    ] [099000][2285383]Palavras: 281                     | Tokens: 37                     | Redução: 87%
# [INFO    ] [100000][2286303]Palavras: 163                     | Tokens: 96                     | Redução: 41%
# ................................................................................
# [INFO    ] [101000][2287238]Palavras: 567                     | Tokens: 230                     | Redução: 59%
# [INFO    ] [102000][2288137]Palavras: 523                     | Tokens: 223                     | Redução: 57%
# [INFO    ] [103000][2289114]Palavras: 236                     | Tokens: 95                     | Redução: 60%
# [INFO    ] [104000][2290071]Palavras: 69                     | Tokens: 10                     | Redução: 86%
# [INFO    ] [105000][2291056]Palavras: 146                     | Tokens: 34                     | Redução: 77%
# [INFO    ] [106000][2291975]Palavras: 97                     | Tokens: 6                     | Redução: 94%
# [INFO    ] [107000][2292951]Palavras: 526                     | Tokens: 10                     | Redução: 98%
# [INFO    ] [108000][2294026]Palavras: 174                     | Tokens: 7                     | Redução: 96%
# [INFO    ] [109000][2294998]Palavras: 94                     | Tokens: 4                     | Redução: 96%
# [INFO    ] [110000][2296013]Palavras: 99                     | Tokens: 5                     | Redução: 95%
# ................................................................................
# [INFO    ] [111000][2297005]Palavras: 64                     | Tokens: 17                     | Redução: 73%
# [INFO    ] [112000][2298062]Palavras: 173                     | Tokens: 6                     | Redução: 97%
# [INFO    ] [113000][2299045]Palavras: 115                     | Tokens: 5                     | Redução: 96%
# [INFO    ] [114000][2300085]Palavras: 116                     | Tokens: 17                     | Redução: 85%
# [INFO    ] [115000][2301035]Palavras: 665                     | Tokens: 320                     | Redução: 52%
# [INFO    ] [116000][2301963]Palavras: 145                     | Tokens: 9                     | Redução: 94%
# [INFO    ] [117000][2302979]Palavras: 118                     | Tokens: 12                     | Redução: 90%
# [INFO    ] [118000][2303922]Palavras: 41                     | Tokens: 9                     | Redução: 78%
# [INFO    ] [119000][2304924]Palavras: 151                     | Tokens: 15                     | Redução: 90%
# [INFO    ] [120000][2305876]Palavras: 108                     | Tokens: 16                     | Redução: 85%
# ................................................................................
# [INFO    ] [121000][2306865]Palavras: 61                     | Tokens: 33                     | Redução: 46%
# [INFO    ] [122000][2307881]Palavras: 513                     | Tokens: 131                     | Redução: 74%
# [INFO    ] [123000][2308754]Palavras: 85                     | Tokens: 20                     | Redução: 76%
# [INFO    ] [124000][2309795]Palavras: 2015                     | Tokens: 903                     | Redução: 55%
# [INFO    ] [125000][2310788]Palavras: 186                     | Tokens: 17                     | Redução: 91%
# [INFO    ] [126000][2311765]Palavras: 34                     | Tokens: 2                     | Redução: 94%
# [INFO    ] [127000][2312719]Palavras: 104                     | Tokens: 14                     | Redução: 87%
# [INFO    ] [128000][2313641]Palavras: 51                     | Tokens: 1                     | Redução: 98%
# [INFO    ] Tokenizado 128179 proposicoes em 6870 segundos. Media=18.66 prop/seg
# [INFO    ] Proposições sem ementa e sem inteiro teor: 989

# %%
dfUnificado.loc[dfUnificado['id']==2211661][['id','tokens','descricaoTipo','tema','inteiroTeor']]
dfUnificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149175 entries, 0 to 149174
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              149175 non-null  int64
#  1   uri             149175 non-null  object
#  2   descricaoTipo   149175 non-null  object
#  3   ementa          148186 non-null  object
#  4   anoDataset      149175 non-null  int64
#  5   urlInteiroTeor  148537 non-null  object
#  6   statusExtracao  149175 non-null  int64
#  7   tipoDocumento   149175 non-null  object
#  8   tamanhoEmBytes  149175 non-null  int64
#  9   inteiroTeor     148186 non-null  object
#  10  uriProposicao   53268 non-null   object
#  11  tema            53268 non-null   object
#  12  tokens          148186 non-null  object
#  13  semConteudo     149175 non-null  bool
# dtypes: bool(1), int64(4), object(9)
# memory usage: 16.1+ MB

# %%
dfStopWords = pd.read_csv(f'{DIR_DATASET}stop_words.csv', usecols=['stop_words']) \
                .replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["", ""])

dfStopWords.describe()
# Out:
#        stop_words
# count   596
# unique  592
# top     o
# freq    2

# %%
dfUnificado['qtdTokens'] = dfUnificado.apply(lambda linha: 0 if pd.isna(linha['tokens']) else len(linha['tokens'].split()),axis=1)
dfUnificado.to_csv(f'{DIR_DATASET}/proposicoesUnificado.csv',index=False,sep=';',quoting=csv.QUOTE_ALL,  escapechar="\\")
